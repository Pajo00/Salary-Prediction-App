# %%
# Import neccessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df= pd.read_csv('cleaned_data.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'sql', 'aws', 'excel', 'powerbi_tableau', 'job_simp', 'seniority',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  599.000000   599.000000  599.000000         599.000000  599.000000
# mean     3.728047  1864.841402    0.003339           0.010017   78.363940
# std      0.631726   453.617669    0.057735           0.099664   31.799346
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.400000  1952.000000    0.000000           0.000000   56.000000
# 50%      3.800000  1992.000000    0.000000           0.000000   74.000000
# 75%      4.100000  2007.000000    0.000000           0.000000   95.500000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean   132.368948  105.366444    0.565943   47.542571    0.639399    0.003339
# ...

# %%
# Create histogram to visualite the numeric columns

px.histogram(df, x='Rating')

# %%
px.histogram(df, x='avg_salary')

# %%
px.histogram(df, x='age')

# %%
px.histogram(df, x='desc_len')

# %%
# Create Boxplots to check for outliers

df.boxplot(column= ['age', 'avg_salary', 'Rating'])
px.box(df.age)

# %%
# Correlation between continuous variables

df[['age','avg_salary','Rating','desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.014073 -0.063217  0.124008
# avg_salary  0.014073    1.000000 -0.006070  0.041630
# Rating     -0.063217   -0.006070  1.000000 -0.003968
# desc_len    0.124008    0.041630 -0.003968  1.000000

# %%
# Plot the correlation
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','Rating','desc_len','num_comp']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


# Generate correlation matrix
corr_matrix = df[['age', 'avg_salary', 'Rating', 'desc_len', 'num_comp']].corr()

# Define colorscale
colorscale = [[0, '#FFFFFF'], [1, '#FF0000']]  # Example colorscale

# Create heatmap figure
fig = go.Figure(data=go.Heatmap(
                   z=corr_matrix.values,
                   x=corr_matrix.columns,
                   y=corr_matrix.columns,
                   colorscale=colorscale,
                   hoverongaps = False))

# Update layout
fig.update_layout(title='Correlation Heatmap',
                  )

# Show plot
fig.show()

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'sql', 'aws', 'excel', 'powerbi_tableau', 'job_simp', 'seniority',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
# To visulaize the categorical data

# Selecting categorical columns
df_cat = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 
             'job_state', 'same_state', 'python_yn', 'R_yn', 'sql', 'aws', 'excel', 'powerbi_tableau', 'job_simp', 'seniority']]

# Loop through each column and create a horizontal bar chart
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts().reset_index() # Reset index to convert Series to DataFrame
    cat_num.columns = [i, 'Count'] # Rename columns for clarity
    cat_num_sorted = cat_num.sort_values(by='Count', ascending=False) # Sort values by count
    print("graph for %s column: total = %d" % (i, len(cat_num))) # Print total unique values for the column
    fig = px.bar(cat_num_sorted, x=i, y='Count', color= i)
    fig.update_layout(showlegend=False)
    fig.update_xaxes(tickangle=45) # Rotate x-axis labels for better readability
    fig.show()
# Out:
# graph for Location column: total = 172
# graph for Headquarters column: total = 173
# graph for Size column: total = 8
# graph for Type of ownership column: total = 8
# graph for Industry column: total = 57
# graph for Sector column: total = 24
# graph for Revenue column: total = 13
# graph for company_txt column: total = 299
# graph for job_state column: total = 34
# graph for same_state column: total = 2
# graph for python_yn column: total = 2
# graph for R_yn column: total = 2
# graph for sql column: total = 2
# graph for aws column: total = 2
# graph for excel column: total = 2
# graph for powerbi_tableau column: total = 2
# graph for job_simp column: total = 6
# graph for seniority column: total = 3

# %%
# To visualize the top 10 location, headquarters and company by No of Job Listings

for i in df_cat[['Location','Headquarters','company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:10]
    #cat_num.columns = [i, 'Count']
    print("graph for %s: total = %d" % (i, len(cat_num)))
    fig = px.bar(cat_num,x=cat_num.index, y=cat_num, color= cat_num.index)
    fig.update_traces(textposition='outside')
    fig.update_layout(
    xaxis=dict(title=None),
    yaxis=dict(title=None),
    showlegend=False)
    fig.update_xaxes(tickangle=-45) # Rotate x-axis labels for better readability
    fig.show()
# Out:
# graph for Location: total = 10
# graph for Headquarters: total = 10
# graph for company_txt: total = 10

# %%
# Avg_salry By job title
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# data analyst     67.169355
# data engineer   104.278226
# data scientist  119.070312
# director        130.800000
# manager          79.250000
# mle             126.431818

# %%
# 2. Job Level by Avg_salary
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# data analyst   jr          56.500000
#                na          63.645833
#                senior      80.092593
# data engineer  na          95.597701
#                senior     124.689189
# data scientist jr         106.500000
#                na         110.191038
#                senior     136.780374
# director       na         130.800000
# manager        na          72.833333
#                senior      98.500000
# mle            na         119.133333
#                senior     142.071429

# %%
# To visualize the pivot table
pivot_table = pd.pivot_table(df, index=['job_simp', 'seniority'], values='avg_salary').reset_index()

# Create bar chart figure
fig = go.Figure()

for level in pivot_table['seniority'].unique():
    job_data = pivot_table[pivot_table['seniority'] == level]
    fig.add_trace(go.Bar(
        x=job_data['job_simp'],
        y=job_data['avg_salary'],
        name=level
    ))

# Update layout
fig.update_layout(
    title='Average Salary by Job title and Job level',
    xaxis_title='Job Title',
    yaxis_title='Average Salary',
    barmode= 'stack'
)

# Show plot
fig.show()

# %%
#  top 10 avg salary by job location/state

location=pd.pivot_table(df, index= 'job_state', values='avg_salary').sort_values('avg_salary', ascending=False)[:10]
location
# Out:
#            avg_salary
# job_state
# CA         127.393130
# IL         123.791667
# DC         110.181818
# MA         108.826087
# NC         108.500000
# NJ         105.937500
# TX         105.428571
# MD         104.700000
# NY         102.016129
# MI         100.250000

# %%
# To visualize the above pivot table
# Reset index of location DataFrame
location.reset_index(inplace=True)

# Create bar chart using Plotly Express
fig = px.bar(location, x='job_state', y='avg_salary', title='Top 10 States with Highest Average Salary',
             labels={'job_state': 'Job State', 'avg_salary': 'Average Salary'}, color='job_state')

# Hide legend
fig.update_layout(showlegend=False)

# Show plot
fig.show()

# %%
# To dispaly all the rows
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
# Job title and State by Avg_salary
title= pd.pivot_table(df, index = ['job_state','job_simp'], values = 'avg_salary').sort_values('avg_salary', ascending = False)[:20]
print(title)
title.reset_index(inplace=True)

# Create bar chart using Plotly Express
fig = px.bar(title, x='job_state', y='avg_salary', color='job_simp',
             labels={'job_state': 'Job State', 'avg_salary': 'Average Salary ($)', 'job_simp': 'Job Title'},
             title='Average Salary by Job State and Job Title')

# Update hover text to display formatted salary
fig.update_traces(hovertemplate='<b>%{x}</b><br>%{y}K')

fig.show()
# Out:
#                           avg_salary
# job_state job_simp
# CA        mle             177.300000
# DC        data scientist  149.000000
# IL        data scientist  147.095238
# CA        data scientist  141.047297
# UT        data scientist  140.500000
# IL        mle             133.000000
# MA        director        130.800000
# CA        data engineer   129.540000
# MO        data scientist  127.666667
# NJ        data scientist  125.083333
# NY        mle             125.000000
# PA        mle             120.500000
# NC        data scientist  117.000000
# PA        data scientist  115.800000
# NY        data scientist  115.250000
# MA        data scientist  114.022727
# WI        data scientist  113.500000
# TX        data engineer   113.062500
# NJ        data engineer   112.000000
# MD        data scientist  109.115385

# %%
# Job state by Avg salary where the Job title is Data Scientist

state= pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)[:10]

# to reset the index
state.reset_index(inplace=True)

# Create bar chart using Plotly Express
fig = px.bar(state, x='job_state', y='avg_salary', color='job_state',
             labels={'job_state': 'Job State', 'avg_salary': 'Average Salary ($)', 'job_simp': 'Job Title'},
             title='Average Salary($) by Job State')

# Update hover text to display formatted salary
fig.update_traces(hovertemplate='<b>%{x}</b><br>%{y}K')

fig.show()

# %%
# How does having Python as a skill affect the avg salary based on the company annual revenue

pd.pivot_table(df, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count').sort_index(ascending=False)
# Out:
# python_yn                            0      1
# Revenue
# Unknown / Non-Applicable          56.0  108.0
# Less than $1 million (USD)         1.0    3.0
# $500 million to $1 billion (USD)  18.0   26.0
# $50 to $100 million (USD)         11.0   23.0
# $5 to $10 million (USD)            4.0    9.0
# $5 to $10 billion (USD)            9.0   10.0
# $25 to $50 million (USD)          12.0   16.0
# $2 to $5 billion (USD)            16.0   22.0
# $100 to $500 million (USD)        27.0   44.0
# $10+ billion (USD)                35.0   55.0
# $10 to $25 million (USD)          12.0   16.0
# $1 to $5 million (USD)             NaN    7.0
# $1 to $2 billion (USD)            15.0   44.0

# %%
# To create a world cloud to display the most used words from the Job description

from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


# Concatenate all job descriptions into a single string
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """Remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)
text = " ".join([ele for ele in words_filtered])

# Generate WordCloud
wc = WordCloud(background_color="white", random_state=1, stopwords=STOPWORDS, max_words=2000, width=1500, height=800)
wc.generate(text)

# Convert WordCloud image to array
image = wc.to_array()

# Create a plotly express image
fig = px.imshow(image)

# Update layout
fig.update_layout(width=1500, height=800)
fig.update_layout(
    xaxis=dict(title=None, showticklabels=False),
    yaxis=dict(title=None, showticklabels=False
               ))

# Show plot
fig.show()
